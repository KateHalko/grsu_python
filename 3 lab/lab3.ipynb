# %% [markdown]
# # Лабораторная работа 3. Основы анализа данных Pandas. Часть 1. Простой датафрейм

# %% [markdown]
# Создайте таблицу

# %%
tb = [[3, 1, 2], [4, 5, 6]]

# %% [markdown]
# Выведите первую строку:

# %%
tb[0]
# Out:
# [3, 1, 2]

# %% [markdown]
# Подключим библиотеку Pandas

# %%
import pandas as pd

# %% [markdown]
# Давайте сделаем dataframe из нашей таблицы.

# %%
df = pd.DataFrame(tb)

# %%
df
# Out:
#    0  1  2
# 0  3  1  2
# 1  4  5  6

# %% [markdown]
# Выведите первый столбец с заголовками.

# %%
df[0]
# Out:
# 0    3
# 1    4
# Name: 0, dtype: int64

# %% [markdown]
# Выведите первую строку с заголовками.

# %%
df[:1]
# Out:
#    0  1  2
# 0  3  1  2

# %% [markdown]
# Выведите вторую строку.

# %%
df.iloc[1]
# Out:
# 0    4
# 1    5
# 2    6
# Name: 1, dtype: int64

# %% [markdown]
# Загрузим файл в Pandas. Выведите результат.

# %%
df = pd.read_csv(
    "lab3_1.csv"
)
df
# Out:
#      task   group10  group2  group3  group4
# 0  python       1.0     2.0     3.0     2.0
# 1     c++       2.3     1.2     2.2     1.2
# 2      c#       2.1     2.3     2.3     2.2
# 3    java       4.0     2.5     2.5     1.2
# 4     php       6.0     5.0     4.0     5.0

# %% [markdown]
# Верхняя строчка выделена полужирным т.к. рассматривается не как строчка с данными, а как строчка с именами столбцов. К столбцам можно обращаться по имени. Обратитесь к столбцу "group10"

# %%
de = df[' group10']
de
# Out:
# 0    1.0
# 1    2.3
# 2    2.1
# 3    4.0
# 4    6.0
# Name:  group10, dtype: float64

# %% [markdown]
# У строк по умолчанию нет имён, и им присваивются номера (левая полужирная колонка). Можно загрузить файл таким образом, чтобы первый столбец рассматривался как столбец с именами строк.

# %%
df = pd.read_csv(
    "lab3_1.csv",
    index_col=0
)
df
# Out:
#          group10  group2  group3  group4
# task
# python       1.0     2.0     3.0     2.0
# c++          2.3     1.2     2.2     1.2
# c#           2.1     2.3     2.3     2.2
# java         4.0     2.5     2.5     1.2
# php          6.0     5.0     4.0     5.0

# %% [markdown]
# Обратитесь к строке "python".

# %%
d = df[:1]
d
# Out:
#          group10  group2  group3  group4
# task
# python       1.0     2.0     3.0     2.0

# %% [markdown]
# Убрать "task" можно следующим образом.

# %%
df.index.name = None
df
# Out:
#          group10  group2  group3  group4
# python       1.0     2.0     3.0     2.0
# c++          2.3     1.2     2.2     1.2
# c#           2.1     2.3     2.3     2.2
# java         4.0     2.5     2.5     1.2
# php          6.0     5.0     4.0     5.0

# %% [markdown]
# Обратитесь к конткретному элементу таблицы.

# %%
d2=df.loc['c#','group4']
d2
# Out:
# 2.2

# %% [markdown]
# Переименуйте столбец group10 в group1

# %%
df=df.rename(columns={' group10': 'group1'})
df
# Out:
#         group1  group2  group3  group4
# python     1.0     2.0     3.0     2.0
# c++        2.3     1.2     2.2     1.2
# c#         2.1     2.3     2.3     2.2
# java       4.0     2.5     2.5     1.2
# php        6.0     5.0     4.0     5.0

# %% [markdown]
# Сделайте срез из 3й и 4й строки.

# %%
df1 = df.iloc[2:4,:]
df1
# Out:
#       group1  group2  group3  group4
# c#       2.1     2.3     2.3     2.2
# java     4.0     2.5     2.5     1.2

# %% [markdown]
# Сделайте срез из 2ого и 3его столбов.

# %%
df2=df.iloc[:,1:3]
df2
# Out:
#         group2  group3
# python     2.0     3.0
# c++        1.2     2.2
# c#         2.3     2.3
# java       2.5     2.5
# php        5.0     4.0

# %% [markdown]
# Получите все строки, соответствующие отметкам по которым group1 получила оценку выше тройки

# %%
df3=df[df.group1>3]
df3
# Out:
#       group1  group2  group3  group4
# java     4.0     2.5     2.5     1.2
# php      6.0     5.0     4.0     5.0

# %% [markdown]
# Посчитать среднюю отметку для каждого предмета.

# %%
df.mean()
# Out:
# group1    3.08
# group2    2.60
# group3    2.80
# group4    2.32
# dtype: float64

# %% [markdown]
# Посчитать среднюю отметку для каждого языка (используйте транспонирование ".T").

# %%
df4 = df.T
df4.mean()
# Out:
# python    2.000
# c++       1.725
# c#        2.225
# java      2.550
# php       5.000
# dtype: float64

# %% [markdown]
# Тоже самое, только используйте направление (axis).

# %%
df5=df.mean(axis=1)
df5
# Out:
# python    2.000
# c++       1.725
# c#        2.225
# java      2.550
# php       5.000
# dtype: float64

# %% [markdown]
# Найдите min для языков.

# %%
df.min(axis=1)
# Out:
# python    1.0
# c++       1.2
# c#        2.1
# java      1.2
# php       4.0
# dtype: float64

# %% [markdown]
# Найдите max для языков.

# %%
df.max(axis=1)
# Out:
# python    3.0
# c++       2.3
# c#        2.3
# java      4.0
# php       6.0
# dtype: float64

# %% [markdown]
# Тоже самое с группами.

# %%
df.max()
# Out:
# group1    6.0
# group2    5.0
# group3    4.0
# group4    5.0
# dtype: float64

# %% [markdown]
# # Часть 2. Более сложный датафрейм

# %% [markdown]
# Далее будем использовать открытые данные Москвы.

# %%
df = pd.read_csv(
    "lab3_2.csv",
    sep=';'
)

# %% [markdown]
# Таблица большая, выведем несколько строк df.head()

# %%
df.head()
# Out:
#    ROWNUM                                             Region  \
# 0       1  город Москва (за исключением Троицкого и Новом...
# 1       2  город Москва (за исключением Троицкого и Новом...
# 2       3  город Москва (за исключением Троицкого и Новом...
# 3       4  город Москва (за исключением Троицкого и Новом...
# 4       5  город Москва (за исключением Троицкого и Новом...
#
#               TariffItem UnitOfMeasure   StartDate     EndDate  \
# 0  Горячее водоснабжение     руб/куб.м  01.01.2012  30.06.2012
# 1          Водоотведение     руб/куб.м  01.01.2012  30.06.2012
# 2                    Газ      руб/кв.м  01.07.2012  31.08.2012
# 3         Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 4         Электроэнергия     руб/кВт.ч  01.01.2012  30.06.2012
#
#   MeasureDeviceAvail StoveType                         ConsumptionTime  \
# 0                 да       NaN                                     NaN
# 1                 да       NaN                                     NaN
# 2                нет       NaN                                     NaN
# 3                 да   газовая  с 07:00 по 23:00 ч (двухтарифный учет)
# 4                 да   газовая  с 23:00 по 07:00 ч (двухтарифный учет)
#
#                            ConsumptionTarget  \
# 0                                        NaN
# 1                                        NaN
# 2  дома с отоплением от газовых нагревателей
# 3                           на бытовые нужды
# 4                           на бытовые нужды
#
#                                               Agency  TariffValue  global_id  \
# 0  ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       105.45   19693618
# 1                                МГУП «Мосводоканал»        16.65   19693667
# 2                  ООО «Газпром межрегионгаз Москва»        25.61   19693682
# 3                                ОАО «Мосэнергосбыт»         4.03   19693607
# 4                                ОАО «Мосэнергосбыт»         0.95   19693669
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# Выведите столбец ROWNUM

# %%
df['ROWNUM'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: ROWNUM, dtype: int64

# %% [markdown]
# Не все так просто. Ответ - нет такого столбца. Но он же есть!

# %% [markdown]
# Воспользуйтесь командой list для вывода столбцов.

# %%
list(df)
# Out:
# ['ROWNUM',
#  'Region',
#  'TariffItem',
#  'UnitOfMeasure',
#  'StartDate',
#  'EndDate',
#  'MeasureDeviceAvail',
#  'StoveType',
#  'ConsumptionTime',
#  'ConsumptionTarget',
#  'Agency',
#  'TariffValue',
#  'global_id',
#  'Unnamed: 13']

# %% [markdown]
# Перед ROWNUM есть невидимый символ, кодирующийся как \ufeff. Чтобы его не считать, нужно использовать encoding='utf-8-sig'

# %%
df = pd.read_csv(
    "lab3_2.csv",
    sep=';',
    
    encoding = 'utf-8-sig'
)
df
# Out:
#     ROWNUM                                             Region  \
# 0        1  город Москва (за исключением Троицкого и Новом...
# 1        2  город Москва (за исключением Троицкого и Новом...
# 2        3  город Москва (за исключением Троицкого и Новом...
# 3        4  город Москва (за исключением Троицкого и Новом...
# 4        5  город Москва (за исключением Троицкого и Новом...
# 5        6  город Москва (за исключением Троицкого и Новом...
# 6        7                                       город Москва
# 7        8  город Москва (за исключением Троицкого и Новом...
# 8        9  город Москва (за исключением Троицкого и Новом...
# 9       10  город Москва (за исключением Троицкого и Новом...
# 10      11  город Москва (за исключением Троицкого и Новом...
# 11      12  город Москва (за исключением Троицкого и Новом...
# 12      13  город Москва (за исключением Троицкого и Новом...
# 13      14                                       город Москва
# 14      15  город Москва (за исключением Троицкого и Новом...
# 15      16  город Москва (за исключением Троицкого и Новом...
# 16      17  город Москва (за исключением Троицкого и Новом...
# 17      18  город Москва (за исключением Троицкого и Новом...
# 18      19  город Москва (за исключением Троицкого и Новом...
# 19      20  город Москва (за исключением Троицкого и Новом...
# 20      21  город Москва (за исключением Троицкого и Новом...
# 21      22  город Москва (за исключением Троицкого и Новом...
# 22      23  город Москва (за исключением Троицкого и Новом...
# 23      24  город Москва (за исключением Троицкого и Новом...
# 24      25  город Москва (за исключением Троицкого и Новом...
# 25      26  город Москва (за исключением Троицкого и Новом...
# 26      27  город Москва (за исключением Троицкого и Новом...
# 27      28  город Москва (за исключением Троицкого и Новом...
# 28      29  город Москва (за исключением Троицкого и Новом...
# 29      30  город Москва (за исключением Троицкого и Новом...
# ..     ...                                                ...
# 41      42  город Москва (за исключением Троицкого и Новом...
# 42      43  город Москва (за исключением Троицкого и Новом...
# 43      44  город Москва (за исключением Троицкого и Новом...
# 44      45  город Москва (за исключением Троицкого и Новом...
# 45      46  город Москва (за исключением Троицкого и Новом...
# 46      47  город Москва (за исключением Троицкого и Новом...
# 47      48  город Москва (за исключением Троицкого и Новом...
# 48      49  город Москва (за исключением Троицкого и Новом...
# 49      50  город Москва (за исключением Троицкого и Новом...
# 50      51  город Москва (за исключением Троицкого и Новом...
# 51      52  город Москва (за исключением Троицкого и Новом...
# 52      53  город Москва (за исключением Троицкого и Новом...
# 53      54  город Москва (за исключением Троицкого и Новом...
# 54      55  город Москва (за исключением Троицкого и Новом...
# 55      56  город Москва (за исключением Троицкого и Новом...
# 56      57  город Москва (за исключением Троицкого и Новом...
# 57      58  город Москва (за исключением Троицкого и Новом...
# 58      59  город Москва (за исключением Троицкого и Новом...
# 59      60  город Москва (за исключением Троицкого и Новом...
# 60      61  город Москва (за исключением Троицкого и Новом...
# 61      62  город Москва (за исключением Троицкого и Новом...
# 62      63  город Москва (за исключением Троицкого и Новом...
# 63      64  город Москва (за исключением Троицкого и Новом...
# 64      65  город Москва (за исключением Троицкого и Новом...
# 65      66  город Москва (за исключением Троицкого и Новом...
# 66      67  город Москва (за исключением Троицкого и Новом...
# 67      68  город Москва (за исключением Троицкого и Новом...
# 68      69  город Москва (за исключением Троицкого и Новом...
# 69      70  город Москва (за исключением Троицкого и Новом...
# 70      71  город Москва (за исключением Троицкого и Новом...
#
#                 TariffItem   UnitOfMeasure   StartDate     EndDate  \
# 0    Горячее водоснабжение       руб/куб.м  01.01.2012  30.06.2012
# 1            Водоотведение       руб/куб.м  01.01.2012  30.06.2012
# 2                      Газ        руб/кв.м  01.07.2012  31.08.2012
# 3           Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 4           Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 5           Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 6                      Газ       руб/куб.м  11.01.2011  15.01.2012
# 7                      Газ       руб/куб.м  15.01.2012  30.06.2012
# 8           Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 9           Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 10                     Газ       руб/куб.м  01.07.2012  31.12.2012
# 11                     Газ  руб/1000 куб.м  15.01.2012  30.06.2012
# 12                     Газ       руб/куб.м  01.07.2012  31.12.2012
# 13                     Газ       руб/куб.м  11.01.2011  15.01.2012
# 14                     Газ         руб/чел  01.01.2012  30.06.2012
# 15          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 16   Горячее водоснабжение       руб/куб.м  01.09.2012  31.12.2012
# 17          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 18          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 19          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 20   Горячее водоснабжение       руб/куб.м  01.07.2012  31.08.2012
# 21                     Газ       руб/куб.м  15.01.2012  30.06.2012
# 22                     Газ         руб/чел  01.07.2012  31.12.2012
# 23                     Газ       руб/куб.м  01.07.2012  31.12.2012
# 24          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 25               Отопление        руб/Гкал  01.09.2012  31.12.2012
# 26           Водоотведение       руб/куб.м  01.09.2012  31.12.2012
# 27          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 28          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 29          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# ..                     ...             ...         ...         ...
# 41          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 42           Водоотведение       руб/куб.м  01.07.2012  31.08.2012
# 43          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 44          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 45                     Газ         руб/чел  01.07.2012  31.12.2012
# 46          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 47          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 48          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 49          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 50   Горячее водоснабжение       руб/куб.м  01.07.2012  31.08.2012
# 51                     Газ        руб/кв.м  01.01.2012  30.06.2012
# 52         Твердое топливо           руб/т  01.01.2012  31.12.2012
# 53               Отопление        руб/Гкал  01.01.2012  30.06.2012
# 54  Холодное водоснабжение       руб/куб.м  01.07.2012  31.08.2012
# 55          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 56          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 57          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 58          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 59                     Газ  руб/1000 куб.м  01.07.2012  31.12.2012
# 60  Холодное водоснабжение       руб/куб.м  01.01.2012  30.06.2012
# 61                     Газ  руб/1000 куб.м  15.01.2012  30.06.2012
# 62  Холодное водоснабжение       руб/куб.м  01.09.2012  31.12.2012
# 63                     Газ  руб/1000 куб.м  01.07.2012  31.12.2012
# 64               Отопление        руб/Гкал  01.07.2012  31.08.2012
# 65                     Газ         руб/чел  01.01.2012  30.06.2012
# 66          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 67          Электроэнергия       руб/кВт.ч  01.01.2012  30.06.2012
# 68          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 69          Электроэнергия       руб/кВт.ч  01.07.2012  31.07.2012
# 70                     Газ       руб/куб.м  15.01.2012  30.06.2012
#
#    MeasureDeviceAvail      StoveType  \
# 0                  да            NaN
# 1                  да            NaN
# 2                 нет            NaN
# 3                  да        газовая
# 4                  да        газовая
# 5                  да        газовая
# 6                  да            NaN
# 7              да/нет            NaN
# 8                  да  электрическая
# 9                  да  электрическая
# 10             да/нет            NaN
# 11             да/нет            NaN
# 12             да/нет            NaN
# 13                 да            NaN
# 14                нет            NaN
# 15                 да        газовая
# 16                 да            NaN
# 17                 да        газовая
# 18                 да  электрическая
# 19                 да  электрическая
# 20                 да            NaN
# 21             да/нет            NaN
# 22                нет            NaN
# 23             да/нет            NaN
# 24                 да        газовая
# 25                 да            NaN
# 26                 да            NaN
# 27                 да        газовая
# 28                 да        газовая
# 29                 да        газовая
# ..                ...            ...
# 41                 да  электрическая
# 42                 да            NaN
# 43                 да        газовая
# 44                 да  электрическая
# 45                нет            NaN
# 46                 да  электрическая
# 47                 да  электрическая
# 48                 да  электрическая
# 49                 да        газовая
# 50                 да            NaN
# 51                нет            NaN
# 52                нет            NaN
# 53                 да            NaN
# 54                 да            NaN
# 55                 да        газовая
# 56                 да        газовая
# 57                 да  электрическая
# 58                 да  электрическая
# 59             да/нет            NaN
# 60                 да            NaN
# 61             да/нет            NaN
# 62                 да            NaN
# 63             да/нет            NaN
# 64                 да            NaN
# 65                нет            NaN
# 66                 да        газовая
# 67                 да  электрическая
# 68                 да  электрическая
# 69                 да  электрическая
# 70             да/нет            NaN
#
#                               ConsumptionTime  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3      с 07:00 по 23:00 ч (двухтарифный учет)
# 4      с 23:00 по 07:00 ч (двухтарифный учет)
# 5     с 21:00 по 23:00 ч (многотарифный учет)
# 6                                         NaN
# 7                                         NaN
# 8     с 17:00 по 21:00 ч (многотарифный учет)
# 9      с 23:00 по 07:00 ч (двухтарифный учет)
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15    с 10:00 по 17:00 ч (многотарифный учет)
# 16                                        NaN
# 17    с 23:00 по 07:00 ч (многотарифный учет)
# 18    с 21:00 по 23:00 ч (многотарифный учет)
# 19    с 10:00 по 17:00 ч (многотарифный учет)
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24    с 07:00 по 10:00 ч (многотарифный учет)
# 25                                        NaN
# 26                                        NaN
# 27    с 10:00 по 17:00 ч (многотарифный учет)
# 28    с 21:00 по 23:00 ч (многотарифный учет)
# 29    с 07:00 по 10:00 ч (многотарифный учет)
# ..                                        ...
# 41    с 07:00 по 10:00 ч (многотарифный учет)
# 42                                        NaN
# 43     с 23:00 по 07:00 ч (двухтарифный учет)
# 44    с 23:00 по 07:00 ч (многотарифный учет)
# 45                                        NaN
# 46    с 23:00 по 07:00 ч (многотарифный учет)
# 47    с 07:00 по 10:00 ч (многотарифный учет)
# 48     с 07:00 по 23:00 ч (двухтарифный учет)
# 49    с 23:00 по 07:00 ч (многотарифный учет)
# 50                                        NaN
# 51                                        NaN
# 52                                        NaN
# 53                                        NaN
# 54                                        NaN
# 55    с 17:00 по 21:00 ч (многотарифный учет)
# 56  без дифференциации по времени потребления
# 57     с 23:00 по 07:00 ч (двухтарифный учет)
# 58  без дифференциации по времени потребления
# 59                                        NaN
# 60                                        NaN
# 61                                        NaN
# 62                                        NaN
# 63                                        NaN
# 64                                        NaN
# 65                                        NaN
# 66    с 17:00 по 21:00 ч (многотарифный учет)
# 67  без дифференциации по времени потребления
# 68    с 17:00 по 21:00 ч (многотарифный учет)
# 69     с 07:00 по 23:00 ч (двухтарифный учет)
# 70                                        NaN
#
#                                     ConsumptionTarget  \
# 0                                                 NaN
# 1                                                 NaN
# 2           дома с отоплением от газовых нагревателей
# 3                                    на бытовые нужды
# 4                                    на бытовые нужды
# 5                                    на бытовые нужды
# 6   на приготовление пищи и горячее водоснабжение ...
# 7   на нагрев воды с использованием газового водон...
# 8                                    на бытовые нужды
# 9                                    на бытовые нужды
# 10  на нагрев воды с использованием газового водон...
# 11  на отопление с одновременным использованием га...
# 12  на приготовление пищи и нагрев воды с использо...
# 13  на отопление жилых помещений, а также в случае...
# 14  при наличии в квартире газовой плиты и отсутст...
# 15                                   на бытовые нужды
# 16                                                NaN
# 17                                   на бытовые нужды
# 18                                   на бытовые нужды
# 19                                   на бытовые нужды
# 20                                                NaN
# 21  на приготовление пищи и нагрев воды с использо...
# 22  при наличии в квартире газовой плиты и газовог...
# 23  на приготовление пищи и нагрев воды с использо...
# 24                                   на бытовые нужды
# 25                                                NaN
# 26                                                NaN
# 27                                   на бытовые нужды
# 28                                   на бытовые нужды
# 29                                   на бытовые нужды
# ..                                                ...
# 41                                   на бытовые нужды
# 42                                                NaN
# 43                                   на бытовые нужды
# 44                                   на бытовые нужды
# 45  при наличии в квартире газовой плиты и централ...
# 46                                   на бытовые нужды
# 47                                   на бытовые нужды
# 48                                   на бытовые нужды
# 49                                   на бытовые нужды
# 50                                                NaN
# 51          дома с отоплением от газовых нагревателей
# 52  твердое топливо (уголь), поставляемое населени...
# 53                                                NaN
# 54                                                NaN
# 55                                   на бытовые нужды
# 56                                   на бытовые нужды
# 57                                   на бытовые нужды
# 58                                   на бытовые нужды
# 59  на отопление с одновременным использованием га...
# 60                                                NaN
# 61  на отопление и (или) выработку электрической э...
# 62                                                NaN
# 63  на отопление и (или) выработку электрической э...
# 64                                                NaN
# 65  при наличии в квартире газовой плиты и централ...
# 66                                   на бытовые нужды
# 67                                   на бытовые нужды
# 68                                   на бытовые нужды
# 69                                   на бытовые нужды
# 70  на приготовление пищи и нагрев воды с использо...
#
#                                                Agency  TariffValue  global_id  \
# 0   ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       105.45   19693618
# 1                                 МГУП «Мосводоканал»        16.65   19693667
# 2                   ООО «Газпром межрегионгаз Москва»        25.61   19693682
# 3                                 ОАО «Мосэнергосбыт»         4.03   19693607
# 4                                 ОАО «Мосэнергосбыт»         0.95   19693669
# 5                                 ОАО «Мосэнергосбыт»         3.20   19693597
# 6                                  ООО «Мосрегионгаз»         4.09   19693595
# 7                   ООО «Газпром межрегионгаз Москва»         4.09   19693684
# 8                                 ОАО «Мосэнергосбыт»         2.66   19693673
# 9                                 ОАО «Мосэнергосбыт»         0.71   19693675
# 10                  ООО «Газпром межрегионгаз Москва»         4.70   19693624
# 11                  ООО «Газпром межрегионгаз Москва»      2930.00   19693625
# 12                  ООО «Газпром межрегионгаз Москва»         4.70   19693623
# 13                                 ООО «Мосрегионгаз»         2.93   19693594
# 14                  ООО «Газпром межрегионгаз Москва»        42.49   19693680
# 15                                ОАО «Мосэнергосбыт»         3.39   19693609
# 16                        ОАО «Мосэнерго» и ОАО «МТК»        93.38   19693620
# 17                                ОАО «Мосэнергосбыт»         1.01   19693608
# 18                                ОАО «Мосэнергосбыт»         2.24   19693603
# 19                                ОАО «Мосэнергосбыт»         2.24   19693602
# 20  ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       111.44   19693303
# 21                  ООО «Газпром межрегионгаз Москва»         4.09   19693685
# 22                  ООО «Газпром межрегионгаз Москва»        97.76   19693306
# 23                  ООО «Газпром межрегионгаз Москва»         4.70   19693307
# 24                                ОАО «Мосэнергосбыт»         3.80   19693299
# 25  ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...      1440.50   19693302
# 26                                МГУП «Мосводоканал»        19.00   19693387
# 27                                ОАО «Мосэнергосбыт»         3.20   19693671
# 28                                ОАО «Мосэнергосбыт»         3.39   19693674
# 29                                ОАО «Мосэнергосбыт»         4.03   19693300
# ..                                                ...          ...        ...
# 41                                ОАО «Мосэнергосбыт»         2.66   19693604
# 42                                МГУП «Мосводоканал»        18.20   19693668
# 43                                ОАО «Мосэнергосбыт»         1.01   19693606
# 44                                ОАО «Мосэнергосбыт»         0.67   19693672
# 45                  ООО «Газпром межрегионгаз Москва»        39.01   19693305
# 46                                ОАО «Мосэнергосбыт»         0.71   19693677
# 47                                ОАО «Мосэнергосбыт»         2.82   19693613
# 48                                ОАО «Мосэнергосбыт»         2.66   19693601
# 49                                ОАО «Мосэнергосбыт»         0.95   19693670
# 50                        ОАО «Мосэнерго» и ОАО «МТК»        89.68   19693619
# 51                  ООО «Газпром межрегионгаз Москва»        22.27   19693622
# 52                                       ОАО «Мосгаз»      1126.00   19693629
# 53                        ОАО «Мосэнерго» и ОАО «МТК»       989.53   19693616
# 54                                МГУП «Мосводоканал»        25.61   19693807
# 55                                ОАО «Мосэнергосбыт»         3.80   19693598
# 56                                ОАО «Мосэнергосбыт»         4.02   19693605
# 57                                ОАО «Мосэнергосбыт»         0.67   19693600
# 58                                ОАО «Мосэнергосбыт»         2.81   19693610
# 59                  ООО «Газпром межрегионгаз Москва»      3370.00   19693626
# 60                                МГУП «Мосводоканал»        23.31   19693806
# 61                  ООО «Газпром межрегионгаз Москва»      2930.00   19693627
# 62                                МГУП «Мосводоканал»        26.75   19693297
# 63                  ООО «Газпром межрегионгаз Москва»      3370.00   19693628
# 64  ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...      1385.32   19693615
# 65                  ООО «Газпром межрегионгаз Москва»        33.91   19693679
# 66                                ОАО «Мосэнергосбыт»         4.03   19693301
# 67                                ОАО «Мосэнергосбыт»         2.65   19693599
# 68                                ОАО «Мосэнергосбыт»         2.82   19693614
# 69                                ОАО «Мосэнергосбыт»         2.82   19693676
# 70                  ООО «Газпром межрегионгаз Москва»         4.09   19693683
#
#     Unnamed: 13
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
# 68          NaN
# 69          NaN
# 70          NaN
#
# [71 rows x 14 columns]

# %% [markdown]
# Покажите, что ошибка исправлена (df['ROWNUM'])

# %%
df['ROWNUM'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: ROWNUM, dtype: int64

# %% [markdown]
# Данных столбец нам в этом виде не понадобится. Сделаейте его индексом строк.

# %%
df = pd.read_csv(
    "lab3_2.csv",
    sep=';',
    encoding = 'utf-8-sig',
    index_col=0
)

# %% [markdown]
# Продемонстрируйте.

# %%
df.head()
# Out:
#                                                    Region  \
# ROWNUM
# 1       город Москва (за исключением Троицкого и Новом...
# 2       город Москва (за исключением Троицкого и Новом...
# 3       город Москва (за исключением Троицкого и Новом...
# 4       город Москва (за исключением Троицкого и Новом...
# 5       город Москва (за исключением Троицкого и Новом...
#
#                    TariffItem UnitOfMeasure   StartDate     EndDate  \
# ROWNUM
# 1       Горячее водоснабжение     руб/куб.м  01.01.2012  30.06.2012
# 2               Водоотведение     руб/куб.м  01.01.2012  30.06.2012
# 3                         Газ      руб/кв.м  01.07.2012  31.08.2012
# 4              Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 5              Электроэнергия     руб/кВт.ч  01.01.2012  30.06.2012
#
#        MeasureDeviceAvail StoveType                         ConsumptionTime  \
# ROWNUM
# 1                      да       NaN                                     NaN
# 2                      да       NaN                                     NaN
# 3                     нет       NaN                                     NaN
# 4                      да   газовая  с 07:00 по 23:00 ч (двухтарифный учет)
# 5                      да   газовая  с 23:00 по 07:00 ч (двухтарифный учет)
#
#                                 ConsumptionTarget  \
# ROWNUM
# 1                                             NaN
# 2                                             NaN
# 3       дома с отоплением от газовых нагревателей
# 4                                на бытовые нужды
# 5                                на бытовые нужды
#
#                                                    Agency  TariffValue  \
# ROWNUM
# 1       ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       105.45
# 2                                     МГУП «Мосводоканал»        16.65
# 3                       ООО «Газпром межрегионгаз Москва»        25.61
# 4                                     ОАО «Мосэнергосбыт»         4.03
# 5                                     ОАО «Мосэнергосбыт»         0.95
#
#         global_id  Unnamed: 13
# ROWNUM
# 1        19693618          NaN
# 2        19693667          NaN
# 3        19693682          NaN
# 4        19693607          NaN
# 5        19693669          NaN

# %% [markdown]
#  В таблице собраны разные данные: тарифы на электроэнергию, газ т.д. Запишите в q_gas данные за газ.

# %%
q_gas = df[df['TariffItem'] == 'Газ']
q_gas.head()
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3             руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 7            руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8            руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»      2930.00   19693625          NaN

# %% [markdown]
# Теперь, используя groupby, запишите в groups различные тарифы. Теперь выведите тарифы за Водоотведение.

# %%
groups = df.groupby('TariffItem')
groups.get_group('Газ')
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
# 13      город Москва (за исключением Троицкого и Новом...        Газ
# 14                                           город Москва        Газ
# 15      город Москва (за исключением Троицкого и Новом...        Газ
# 22      город Москва (за исключением Троицкого и Новом...        Газ
# 23      город Москва (за исключением Троицкого и Новом...        Газ
# 24      город Москва (за исключением Троицкого и Новом...        Газ
# 32      город Москва (за исключением Троицкого и Новом...        Газ
# 36      город Москва (за исключением Троицкого и Новом...        Газ
# 46      город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
# 60      город Москва (за исключением Троицкого и Новом...        Газ
# 62      город Москва (за исключением Троицкого и Новом...        Газ
# 64      город Москва (за исключением Троицкого и Новом...        Газ
# 66      город Москва (за исключением Троицкого и Новом...        Газ
# 71      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3             руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 7            руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8            руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 13           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 14           руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 15             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 22           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 23             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 24           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 32             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 36             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 46             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 52            руб/кв.м  01.01.2012  30.06.2012                нет       NaN
# 60      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 62      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 64      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 66             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 71           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
# 13                 NaN  на приготовление пищи и нагрев воды с использо...
# 14                 NaN  на отопление жилых помещений, а также в случае...
# 15                 NaN  при наличии в квартире газовой плиты и отсутст...
# 22                 NaN  на приготовление пищи и нагрев воды с использо...
# 23                 NaN  при наличии в квартире газовой плиты и газовог...
# 24                 NaN  на приготовление пищи и нагрев воды с использо...
# 32                 NaN  при наличии в квартире газовой плиты и газовог...
# 36                 NaN  при наличии в квартире газовой плиты и отсутст...
# 46                 NaN  при наличии в квартире газовой плиты и централ...
# 52                 NaN          дома с отоплением от газовых нагревателей
# 60                 NaN  на отопление с одновременным использованием га...
# 62                 NaN  на отопление и (или) выработку электрической э...
# 64                 NaN  на отопление и (или) выработку электрической э...
# 66                 NaN  при наличии в квартире газовой плиты и централ...
# 71                 NaN  на приготовление пищи и нагрев воды с использо...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»      2930.00   19693625          NaN
# 13      ООО «Газпром межрегионгаз Москва»         4.70   19693623          NaN
# 14                     ООО «Мосрегионгаз»         2.93   19693594          NaN
# 15      ООО «Газпром межрегионгаз Москва»        42.49   19693680          NaN
# 22      ООО «Газпром межрегионгаз Москва»         4.09   19693685          NaN
# 23      ООО «Газпром межрегионгаз Москва»        97.76   19693306          NaN
# 24      ООО «Газпром межрегионгаз Москва»         4.70   19693307          NaN
# 32      ООО «Газпром межрегионгаз Москва»        84.98   19693621          NaN
# 36      ООО «Газпром межрегионгаз Москва»        48.88   19693681          NaN
# 46      ООО «Газпром межрегионгаз Москва»        39.01   19693305          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN
# 60      ООО «Газпром межрегионгаз Москва»      3370.00   19693626          NaN
# 62      ООО «Газпром межрегионгаз Москва»      2930.00   19693627          NaN
# 64      ООО «Газпром межрегионгаз Москва»      3370.00   19693628          NaN
# 66      ООО «Газпром межрегионгаз Москва»        33.91   19693679          NaN
# 71      ООО «Газпром межрегионгаз Москва»         4.09   19693683          NaN

# %% [markdown]
# Выведите список групп.

# %%
groups.groups.keys()
# Out:
# dict_keys(['Водоотведение', 'Газ', 'Горячее водоснабжение', 'Отопление', 'Твердое топливо', 'Холодное водоснабжение', 'Электроэнергия'])

# %% [markdown]
# Посчитайте средние тарифы.

# %%
df.groupby('TariffItem').mean()
# Out:
#                         TariffValue     global_id  Unnamed: 13
# TariffItem
# Водоотведение             17.950000  1.969357e+07          NaN
# Газ                      651.415000  1.969359e+07          NaN
# Горячее водоснабжение    100.095000  1.969352e+07          NaN
# Отопление               1208.423333  1.969363e+07          NaN
# Твердое топливо         1126.000000  1.969363e+07          NaN
# Холодное водоснабжение    25.223333  1.969364e+07          NaN
# Электроэнергия             2.571250  1.969359e+07          NaN

# %% [markdown]
# Далее приведем в порядок тарифы за газ. Вычислите кол-во различных UnitOfMeasure (единица измерения).

# %%
q_gas['UnitOfMeasure'].value_counts()
# Out:
# руб/куб.м         8
# руб/чел           6
# руб/1000 куб.м    4
# руб/кв.м          2
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Замените руб/кв.м на руб/куб.м (это ошибка).

# %%
qkvm = q_gas['UnitOfMeasure'] == 'руб/кв.м'
q_gas[qkvm]
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3           руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 52          руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#        ConsumptionTime                          ConsumptionTarget  \
# ROWNUM
# 3                  NaN  дома с отоплением от газовых нагревателей
# 52                 NaN  дома с отоплением от газовых нагревателей
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %%
q_gas = q_gas.copy()
q_gas.loc[qkvm, 'UnitOfMeasure'] = "руб/куб.м"
q_gas['UnitOfMeasure'].value_counts()
# Out:
# руб/куб.м         10
# руб/чел            6
# руб/1000 куб.м     4
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Все значения в строках где руб/1000 куб.м умножьте на 1000.

# %%
df[df['UnitOfMeasure'] == 'руб/1000 куб.м']
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 12      город Москва (за исключением Троицкого и Новом...        Газ
# 60      город Москва (за исключением Троицкого и Новом...        Газ
# 62      город Москва (за исключением Троицкого и Новом...        Газ
# 64      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 60      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 62      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 64      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 12                 NaN  на отопление с одновременным использованием га...
# 60                 NaN  на отопление с одновременным использованием га...
# 62                 NaN  на отопление и (или) выработку электрической э...
# 64                 NaN  на отопление и (или) выработку электрической э...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 12      ООО «Газпром межрегионгаз Москва»       2930.0   19693625          NaN
# 60      ООО «Газпром межрегионгаз Москва»       3370.0   19693626          NaN
# 62      ООО «Газпром межрегионгаз Москва»       2930.0   19693627          NaN
# 64      ООО «Газпром межрегионгаз Москва»       3370.0   19693628          NaN

# %%
df[df['UnitOfMeasure'] == 'руб/1000 куб.м']['TariffValue']*1000
# Out:
# ROWNUM
# 12    2930000.0
# 60    3370000.0
# 62    2930000.0
# 64    3370000.0
# Name: TariffValue, dtype: float64

# %% [markdown]
# Измените единицу измерения на руб/куб.м.

# %%
q_gas.loc[(q_gas['UnitOfMeasure'] == 'руб/1000 куб.м')|(q_gas['UnitOfMeasure']=='руб/куб.м')]
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
# 13      город Москва (за исключением Троицкого и Новом...        Газ
# 14                                           город Москва        Газ
# 22      город Москва (за исключением Троицкого и Новом...        Газ
# 24      город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
# 60      город Москва (за исключением Троицкого и Новом...        Газ
# 62      город Москва (за исключением Троицкого и Новом...        Газ
# 64      город Москва (за исключением Троицкого и Новом...        Газ
# 71      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3            руб/куб.м  01.07.2012  31.08.2012                нет       NaN
# 7            руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8            руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 13           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 14           руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 22           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 24           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 52           руб/куб.м  01.01.2012  30.06.2012                нет       NaN
# 60      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 62      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 64      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 71           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
# 13                 NaN  на приготовление пищи и нагрев воды с использо...
# 14                 NaN  на отопление жилых помещений, а также в случае...
# 22                 NaN  на приготовление пищи и нагрев воды с использо...
# 24                 NaN  на приготовление пищи и нагрев воды с использо...
# 52                 NaN          дома с отоплением от газовых нагревателей
# 60                 NaN  на отопление с одновременным использованием га...
# 62                 NaN  на отопление и (или) выработку электрической э...
# 64                 NaN  на отопление и (или) выработку электрической э...
# 71                 NaN  на приготовление пищи и нагрев воды с использо...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»      2930.00   19693625          NaN
# 13      ООО «Газпром межрегионгаз Москва»         4.70   19693623          NaN
# 14                     ООО «Мосрегионгаз»         2.93   19693594          NaN
# 22      ООО «Газпром межрегионгаз Москва»         4.09   19693685          NaN
# 24      ООО «Газпром межрегионгаз Москва»         4.70   19693307          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN
# 60      ООО «Газпром межрегионгаз Москва»      3370.00   19693626          NaN
# 62      ООО «Газпром межрегионгаз Москва»      2930.00   19693627          NaN
# 64      ООО «Газпром межрегионгаз Москва»      3370.00   19693628          NaN
# 71      ООО «Газпром межрегионгаз Москва»         4.09   19693683          NaN

# %%
q_gas['UnitOfMeasure'].value_counts()
# Out:
# руб/куб.м         10
# руб/чел            6
# руб/1000 куб.м     4
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Для всех таких строк вызовите метод describe().

# %%
df[df['UnitOfMeasure'] == 'руб/куб.м'].describe()
# Out:
#        TariffValue     global_id  Unnamed: 13
# count    20.000000  2.000000e+01          0.0
# mean     38.174000  1.969358e+07          NaN
# std      42.795955  1.643915e+02          NaN
# min       2.930000  1.969330e+07          NaN
# 25%       4.547500  1.969354e+07          NaN
# 50%      18.600000  1.969362e+07          NaN
# 75%      85.885000  1.969368e+07          NaN
# max     116.000000  1.969381e+07          NaN

# %% [markdown]
# # Часть 3. Более сложные запросы

# %% [markdown]
# Из исходной таблицы сделайте выборку тех строк, в которых в качестве единицы измерения указаны руб/кв.м и указан тариф на газ.

# %%
df.loc[(df['UnitOfMeasure']=='руб/кв.м')&(df['TariffItem']=='Газ')]
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3           руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 52          руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#        ConsumptionTime                          ConsumptionTarget  \
# ROWNUM
# 3                  NaN  дома с отоплением от газовых нагревателей
# 52                 NaN  дома с отоплением от газовых нагревателей
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %% [markdown]
# Сделайте такой же запрос через query.

# %%
df.query('UnitOfMeasure == "руб/кв.м" and TariffItem=="Газ"')
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3           руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 52          руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#        ConsumptionTime                          ConsumptionTarget  \
# ROWNUM
# 3                  NaN  дома с отоплением от газовых нагревателей
# 52                 NaN  дома с отоплением от газовых нагревателей
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %% [markdown]
# Далее использовать будем открытые данные Москвы за 2016 год. Используйте для этого файл tariff.json. Преобразуйте в необходимый формат.

# %%
import json

from pandas.io.json import json_normalize

with open('tariff.json') as data_file:
    data=json.load(data_file)
d = json_normalize(data, 'results')
d.to_csv("output.csv", index=False, sep='\t', encoding="utf-8")

# %% [markdown]
# Вычислите средний тарифф.

# %%
df['TariffValue'].mean()
# Out:
# 312.91845070422534

# %% [markdown]
# Придумайте себе два запроса и реализуйте их ниже.

# %%
df.loc[(df['TariffValue']>=3)&(df['TariffItem']=='Электроэнергия')]
# Out:
#                                                    Region      TariffItem  \
# ROWNUM
# 4       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 6       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 16      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 25      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 28      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 29      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 30      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 35      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 38      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 56      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 57      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 67      город Москва (за исключением Троицкого и Новом...  Электроэнергия
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 4          руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
# 6          руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 16         руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
# 25         руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 28         руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 29         руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
# 30         руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
# 35         руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 38         руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 56         руб/кВт.ч  01.01.2012  30.06.2012                 да   газовая
# 57         руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
# 67         руб/кВт.ч  01.07.2012  31.07.2012                 да   газовая
#
#                                   ConsumptionTime ConsumptionTarget  \
# ROWNUM
# 4          с 07:00 по 23:00 ч (двухтарифный учет)  на бытовые нужды
# 6         с 21:00 по 23:00 ч (многотарифный учет)  на бытовые нужды
# 16        с 10:00 по 17:00 ч (многотарифный учет)  на бытовые нужды
# 25        с 07:00 по 10:00 ч (многотарифный учет)  на бытовые нужды
# 28        с 10:00 по 17:00 ч (многотарифный учет)  на бытовые нужды
# 29        с 21:00 по 23:00 ч (многотарифный учет)  на бытовые нужды
# 30        с 07:00 по 10:00 ч (многотарифный учет)  на бытовые нужды
# 35      без дифференциации по времени потребления  на бытовые нужды
# 38         с 07:00 по 23:00 ч (двухтарифный учет)  на бытовые нужды
# 56        с 17:00 по 21:00 ч (многотарифный учет)  на бытовые нужды
# 57      без дифференциации по времени потребления  на бытовые нужды
# 67        с 17:00 по 21:00 ч (многотарифный учет)  на бытовые нужды
#
#                      Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 4       ОАО «Мосэнергосбыт»         4.03   19693607          NaN
# 6       ОАО «Мосэнергосбыт»         3.20   19693597          NaN
# 16      ОАО «Мосэнергосбыт»         3.39   19693609          NaN
# 25      ОАО «Мосэнергосбыт»         3.80   19693299          NaN
# 28      ОАО «Мосэнергосбыт»         3.20   19693671          NaN
# 29      ОАО «Мосэнергосбыт»         3.39   19693674          NaN
# 30      ОАО «Мосэнергосбыт»         4.03   19693300          NaN
# 35      ОАО «Мосэнергосбыт»         3.79   19693298          NaN
# 38      ОАО «Мосэнергосбыт»         3.80   19693596          NaN
# 56      ОАО «Мосэнергосбыт»         3.80   19693598          NaN
# 57      ОАО «Мосэнергосбыт»         4.02   19693605          NaN
# 67      ОАО «Мосэнергосбыт»         4.03   19693301          NaN

# %%
df.loc[df['TariffItem']=='Электроэнергия']
# Out:
#                                                    Region      TariffItem  \
# ROWNUM
# 4       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 5       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 6       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 9       город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 10      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 16      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 18      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 19      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 20      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 25      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 28      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 29      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 30      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 34      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 35      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 38      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 39      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 42      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 44      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 45      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 47      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 48      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 49      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 50      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 56      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 57      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 58      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 59      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 67      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 68      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 69      город Москва (за исключением Троицкого и Новом...  Электроэнергия
# 70      город Москва (за исключением Троицкого и Новом...  Электроэнергия
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail  \
# ROWNUM
# 4          руб/кВт.ч  01.07.2012  31.07.2012                 да
# 5          руб/кВт.ч  01.01.2012  30.06.2012                 да
# 6          руб/кВт.ч  01.01.2012  30.06.2012                 да
# 9          руб/кВт.ч  01.01.2012  30.06.2012                 да
# 10         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 16         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 18         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 19         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 20         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 25         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 28         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 29         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 30         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 34         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 35         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 38         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 39         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 42         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 44         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 45         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 47         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 48         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 49         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 50         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 56         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 57         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 58         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 59         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 67         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 68         руб/кВт.ч  01.01.2012  30.06.2012                 да
# 69         руб/кВт.ч  01.07.2012  31.07.2012                 да
# 70         руб/кВт.ч  01.07.2012  31.07.2012                 да
#
#             StoveType                            ConsumptionTime  \
# ROWNUM
# 4             газовая     с 07:00 по 23:00 ч (двухтарифный учет)
# 5             газовая     с 23:00 по 07:00 ч (двухтарифный учет)
# 6             газовая    с 21:00 по 23:00 ч (многотарифный учет)
# 9       электрическая    с 17:00 по 21:00 ч (многотарифный учет)
# 10      электрическая     с 23:00 по 07:00 ч (двухтарифный учет)
# 16            газовая    с 10:00 по 17:00 ч (многотарифный учет)
# 18            газовая    с 23:00 по 07:00 ч (многотарифный учет)
# 19      электрическая    с 21:00 по 23:00 ч (многотарифный учет)
# 20      электрическая    с 10:00 по 17:00 ч (многотарифный учет)
# 25            газовая    с 07:00 по 10:00 ч (многотарифный учет)
# 28            газовая    с 10:00 по 17:00 ч (многотарифный учет)
# 29            газовая    с 21:00 по 23:00 ч (многотарифный учет)
# 30            газовая    с 07:00 по 10:00 ч (многотарифный учет)
# 34      электрическая    с 21:00 по 23:00 ч (многотарифный учет)
# 35            газовая  без дифференциации по времени потребления
# 38            газовая     с 07:00 по 23:00 ч (двухтарифный учет)
# 39      электрическая    с 10:00 по 17:00 ч (многотарифный учет)
# 42      электрическая    с 07:00 по 10:00 ч (многотарифный учет)
# 44            газовая     с 23:00 по 07:00 ч (двухтарифный учет)
# 45      электрическая    с 23:00 по 07:00 ч (многотарифный учет)
# 47      электрическая    с 23:00 по 07:00 ч (многотарифный учет)
# 48      электрическая    с 07:00 по 10:00 ч (многотарифный учет)
# 49      электрическая     с 07:00 по 23:00 ч (двухтарифный учет)
# 50            газовая    с 23:00 по 07:00 ч (многотарифный учет)
# 56            газовая    с 17:00 по 21:00 ч (многотарифный учет)
# 57            газовая  без дифференциации по времени потребления
# 58      электрическая     с 23:00 по 07:00 ч (двухтарифный учет)
# 59      электрическая  без дифференциации по времени потребления
# 67            газовая    с 17:00 по 21:00 ч (многотарифный учет)
# 68      электрическая  без дифференциации по времени потребления
# 69      электрическая    с 17:00 по 21:00 ч (многотарифный учет)
# 70      электрическая     с 07:00 по 23:00 ч (двухтарифный учет)
#
#        ConsumptionTarget               Agency  TariffValue  global_id  \
# ROWNUM
# 4       на бытовые нужды  ОАО «Мосэнергосбыт»         4.03   19693607
# 5       на бытовые нужды  ОАО «Мосэнергосбыт»         0.95   19693669
# 6       на бытовые нужды  ОАО «Мосэнергосбыт»         3.20   19693597
# 9       на бытовые нужды  ОАО «Мосэнергосбыт»         2.66   19693673
# 10      на бытовые нужды  ОАО «Мосэнергосбыт»         0.71   19693675
# 16      на бытовые нужды  ОАО «Мосэнергосбыт»         3.39   19693609
# 18      на бытовые нужды  ОАО «Мосэнергосбыт»         1.01   19693608
# 19      на бытовые нужды  ОАО «Мосэнергосбыт»         2.24   19693603
# 20      на бытовые нужды  ОАО «Мосэнергосбыт»         2.24   19693602
# 25      на бытовые нужды  ОАО «Мосэнергосбыт»         3.80   19693299
# 28      на бытовые нужды  ОАО «Мосэнергосбыт»         3.20   19693671
# 29      на бытовые нужды  ОАО «Мосэнергосбыт»         3.39   19693674
# 30      на бытовые нужды  ОАО «Мосэнергосбыт»         4.03   19693300
# 34      на бытовые нужды  ОАО «Мосэнергосбыт»         2.37   19693612
# 35      на бытовые нужды  ОАО «Мосэнергосбыт»         3.79   19693298
# 38      на бытовые нужды  ОАО «Мосэнергосбыт»         3.80   19693596
# 39      на бытовые нужды  ОАО «Мосэнергосбыт»         2.37   19693611
# 42      на бытовые нужды  ОАО «Мосэнергосбыт»         2.66   19693604
# 44      на бытовые нужды  ОАО «Мосэнергосбыт»         1.01   19693606
# 45      на бытовые нужды  ОАО «Мосэнергосбыт»         0.67   19693672
# 47      на бытовые нужды  ОАО «Мосэнергосбыт»         0.71   19693677
# 48      на бытовые нужды  ОАО «Мосэнергосбыт»         2.82   19693613
# 49      на бытовые нужды  ОАО «Мосэнергосбыт»         2.66   19693601
# 50      на бытовые нужды  ОАО «Мосэнергосбыт»         0.95   19693670
# 56      на бытовые нужды  ОАО «Мосэнергосбыт»         3.80   19693598
# 57      на бытовые нужды  ОАО «Мосэнергосбыт»         4.02   19693605
# 58      на бытовые нужды  ОАО «Мосэнергосбыт»         0.67   19693600
# 59      на бытовые нужды  ОАО «Мосэнергосбыт»         2.81   19693610
# 67      на бытовые нужды  ОАО «Мосэнергосбыт»         4.03   19693301
# 68      на бытовые нужды  ОАО «Мосэнергосбыт»         2.65   19693599
# 69      на бытовые нужды  ОАО «Мосэнергосбыт»         2.82   19693614
# 70      на бытовые нужды  ОАО «Мосэнергосбыт»         2.82   19693676
#
#         Unnamed: 13
# ROWNUM
# 4               NaN
# 5               NaN
# 6               NaN
# 9               NaN
# 10              NaN
# 16              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 25              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 34              NaN
# 35              NaN
# 38              NaN
# 39              NaN
# 42              NaN
# 44              NaN
# 45              NaN
# 47              NaN
# 48              NaN
# 49              NaN
# 50              NaN
# 56              NaN
# 57              NaN
# 58              NaN
# 59              NaN
# 67              NaN
# 68              NaN
# 69              NaN
# 70              NaN
